# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from tensorflow import keras
from scipy import ndimage
import math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-627d0d95df50> in <module>
#       2 import matplotlib.pyplot as plt
#       3 import cv2
# ----> 4 from tensorflow import keras
#       5 from scipy import ndimage
#       6 import math
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# **IMPORTANDO A IMAGEM DO TEMPLATE PADRÃO**

# %%
#TEMPLATE PADRÃO
template = cv2.imread("./imgs/m3.pgm")
plt.figure(figsize=(20,2))
plt.imshow(template)
amostra = cv2.imread("./imgs/m2_006.jpg")
plt.figure(figsize=(20,2))
plt.imshow(amostra)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-228b29557e47> in <module>
#       2 template = cv2.imread("/imgs/m3.pgm")
#       3 plt.figure(figsize=(20,2))
# ----> 4 plt.imshow(template)
#       5 amostra = cv2.imread("/imgs/m2_006.jpg")
#       6 plt.figure(figsize=(20,2))
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2870         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2871         data=None, **kwargs):
# -> 2872     __ret = gca().imshow(
#    2873         X, cmap=cmap, norm=norm, aspect=aspect,
#    2874         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1350     def inner(ax, *args, data=None, **kwargs):
#    1351         if data is None:
# -> 1352             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1353
#    1354         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5587                               resample=resample, **kwargs)
#    5588
# -> 5589         im.set_data(X)
#    5590         im.set_alpha(alpha)
#    5591         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/image.py in set_data(self, A)
#     698         if (self._A.dtype != np.uint8 and
#     699                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 700             raise TypeError("Image data of dtype {} cannot be converted to "
#     701                             "float".format(self._A.dtype))
#     702
#
# TypeError: Image data of dtype object cannot be converted to float

# %% [markdown]
# **AJUSTANDO O TAMANHO DA IMAGEM**

# %%
col, lin=template.shape[:2]
img = cv2.resize(amostra,(lin,col),interpolation = cv2.INTER_LINEAR)
plt.figure(figsize=(20,2))
plt.imshow(img)
plt.figure(figsize=(20,2))
plt.imshow(template)

# %%
ampliacao = (template.shape[1]*template.shape[0])/(amostra.shape[1]*amostra.shape[0])
print(f"O fator de ampliação é:{ampliacao}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-244e54cd110f> in <module>
# ----> 1 ampliacao = (template.shape[1]*template.shape[0])/(amostra.shape[1]*amostra.shape[0])
#       2 print(f"O fator de ampliação é:{ampliacao}")
#
# NameError: name 'template' is not defined

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_edges = cv2.Canny(img_gray,100, 100, apertureSize=3)
lines = cv2.HoughLinesP(img_edges, 1, math.pi / 180.0, 100, minLineLength=100, maxLineGap=5)

angles = []

for [[x1, y1, x2, y2]] in lines:
    cv2.line(img, (x1, y1), (x2, y2), (255, 0, 0), 2)
    angle = math.degrees(math.atan2(y2 - y1, x2 - x1))
    angles.append(angle)

median_angle = np.median(angles)
img_rotated = ndimage.rotate(img, median_angle)

print(f"Angle is {median_angle:.04f}")
plt.figure(figsize=(20,10))
plt.imshow(template)
plt.figure(figsize=(20,10))
plt.imshow(img_rotated)
# Out:
# Angle is -0.9140

# %% [markdown]
# **APLICANDO TEMPLATE MATCHING**

# %%
tp = cv2.matchTemplate(img_rotated,template,cv2.TM_CCOEFF_NORMED)
plt.figure(figsize=(20,10))
plt.imshow(tp)

# %%
tp = cv2.matchTemplate(img_rotated,template,cv2.TM_CCOEFF_NORMED)
plt.figure(figsize=(20,10))
plt.imshow(tp)

# %%
tp
# Out:
# array([[-0.1466479 , -0.1446077 , -0.14522718],
#        [-0.10923769, -0.10677756, -0.10734601],
#        [-0.07732996, -0.07467603, -0.07533541],
#        [-0.06041487, -0.05774058, -0.05856945],
#        [-0.06603868, -0.06359413, -0.06463454],
#        [-0.08585729, -0.08386125, -0.08507074],
#        [-0.10280577, -0.10112803, -0.10253867],
#        [-0.1142401 , -0.11259235, -0.11391594],
#        [-0.11811174, -0.11640161, -0.11752336],
#        [-0.12004709, -0.11818345, -0.11902747],
#        [-0.12868884, -0.12664136, -0.127164  ],
#        [-0.14460862, -0.14236155, -0.14240557],
#        [-0.15638535, -0.15411061, -0.153926  ]], dtype=float32)
